# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv('test.csv')

# %%
df1
# Out:
#           Unnamed: 0              0
# 0         Unnamed: 0       0.000000
# 1             TARGET       1.000000
# 2       EXT_SOURCE_1       0.083037
# 3       EXT_SOURCE_2       0.262949
# 4       EXT_SOURCE_3       0.139376
# 5   AMT_INCOME_TOTAL  202500.000000
# 6         DAYS_BIRTH   -9461.000000
# 7         AMT_CREDIT  406597.500000
# 8        AMT_ANNUITY   24700.500000
# 9      DAYS_EMPLOYED    -637.000000
# 10      PAYMENT_RATE       0.060749

# %%
dic={"info_client": {"Unnamed: 0": 0.0, "TARGET": 1.0, "EXT_SOURCE_1": 0.0830369673913225, "EXT_SOURCE_2": 0.2629485927471776, "EXT_SOURCE_3": 0.1393757800997895, "AMT_INCOME_TOTAL": 202500.0, "DAYS_BIRTH": -9461.0, "AMT_CREDIT": 406597.5, "AMT_ANNUITY": 24700.5, "DAYS_EMPLOYED": -637.0, "PAYMENT_RATE": 0.0607492667810303}}

# %%
pd.Series(dic['info_client'])['TARGET']
# Out:
# 1.0

# %%
df=pd.read_csv("data_process.csv", low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 df=pd.read_csv("data_process.csv", low_memory=False)
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df
# Out:
#         Unnamed: 0  index  SK_ID_CURR  TARGET  CODE_GENDER  FLAG_OWN_CAR  \
# 0                0      0      100002     1.0            0             0
# 1                1      1      100003     0.0            1             0
# 2                2      2      100004     0.0            0             1
# 3                3      3      100006     0.0            1             0
# 4                4      4      100007     0.0            0             0
# ...            ...    ...         ...     ...          ...           ...
# 356246      356250  48739      456221     NaN            1             0
# 356247      356251  48740      456222     NaN            1             0
# 356248      356252  48741      456223     NaN            1             1
# 356249      356253  48742      456224     NaN            0             0
# 356250      356254  48743      456250     NaN            1             1
#
#         FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  ...  \
# ...

# %%
col=['SK_ID_CURR', 'TARGET','EXT_SOURCE_1','EXT_SOURCE_2','EXT_SOURCE_3', 'AMT_INCOME_TOTAL','DAYS_BIRTH', 'AMT_CREDIT', 'AMT_ANNUITY', 'DAYS_EMPLOYED', 'PAYMENT_RATE']

# %%
df=df[col]

# %%
df=df[~df['TARGET'].isna()]

# %%
df

# %%
pd.read_c

# %%
df.to_csv('data_useful.csv')

# %%
# Out:
#         SK_ID_CURR  TARGET  EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  \
# 0           100002     1.0      0.083037      0.262949      0.139376
# 1           100003     0.0      0.311267      0.622246           NaN
# 2           100004     0.0           NaN      0.555912      0.729567
# 3           100006     0.0           NaN      0.650442           NaN
# 4           100007     0.0           NaN      0.322738           NaN
# ...            ...     ...           ...           ...           ...
# 307502      456251     0.0      0.145570      0.681632           NaN
# 307503      456252     0.0           NaN      0.115992           NaN
# 307504      456253     0.0      0.744026      0.535722      0.218859
# 307505      456254     1.0           NaN      0.514163      0.661024
# 307506      456255     0.0      0.734460      0.708569      0.113922
#
#         AMT_INCOME_TOTAL  DAYS_BIRTH  AMT_CREDIT  AMT_ANNUITY  DAYS_EMPLOYED  \
# ...

# %%
col = ['TARGET', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'DAYS_BIRTH', 'AMT_INCOME_TOTAL', 'AMT_ANNUITY', 'DAYS_EMPLOYED']
df_column = df[col]
corr= df_column.corr()

# %%
corr['TARGET']
# Out:
# TARGET              1.000000
# EXT_SOURCE_1       -0.155317
# EXT_SOURCE_2       -0.160471
# EXT_SOURCE_3       -0.178926
# DAYS_BIRTH          0.078242
# AMT_INCOME_TOTAL   -0.003982
# AMT_ANNUITY        -0.012818
# DAYS_EMPLOYED       0.074957
# Name: TARGET, dtype: float64
